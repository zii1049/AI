# %% [markdown]
# <a href="https://colab.research.google.com/github/zii1049/AI/blob/main/Add_noise_to_the_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('/content/drive/MyDrive/download.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Add Gaussian noise to the image
mean = 20
std_dev = 50
noise = np.random.normal(mean, std_dev, image.shape)
noisy_image = np.clip(image.astype(np.float32) + noise, 0, 255).astype(np.uint8)

# Display the original and noisy images using matplotlib
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(noisy_image)
plt.title('Noisy Image')
plt.axis('off')

plt.show()
